# %%
import pandas as pd
df = pd.read_csv('./data/books.csv')

# %%
df.head()
# Out:
#             authors                                     favorite_quote  \
# 0       Byron Katie  I am a lover of what is- not because I'm a spi...
# 1  Chris Guillebeau  It's your life- so why not be intentional abou...
# 2     Dale Carnegie  Let's not allow ourselves to be upset by small...
# 3       Dan Gilbert  The secret of happiness is variety- but the se...
# 4        Dan Harris  There's no point in being unhappy about things...
#
#                                      One_line_review  \
# 0  Loving What Is gives you four simple questions...
# 1  The Happiness Of Pursuit is a call to take con...
# 2  How To Stop Worrying And Start Living is a sel...
# 3  Stumbling On Happiness examines the capacity o...
# 4  10% Happier gives skeptics an easy "in"to medi...
#
#                                      why_should_read  \
# 0  Byron Katie had a powerful realization at 43 y...
# 1  Chris Guillebeau wrote this book after visitin...
# ...

# %%
df['One_line_review'].str.extract('^([\w%])')
# Out:
#                                                     0
# 0   Loving What Is gives you four simple questions...
# 1   The Happiness Of Pursuit is a call to take con...
# 2   How To Stop Worrying And Start Living is a sel...
# 3   Stumbling On Happiness examines the capacity o...
# 4   10% Happier gives skeptics an easy "in"to medi...
# 5   If You're So Smart- Why Aren't You Happy walks...
# 6   The Power of Now shows you that every minute y...
# 7   Trying Not To Try explores ancient- Chinese ph...
# 8   The Happiness Project will show you how to cha...
# 9   Happier At Home is an instruction manual to tr...
# 10  Ikigai explains how you can live a longer and ...
# 11  The Art Of Happiness is the result of a psychi...
# 12  The Power Of No is an encompassing instruction...
# 13  Wherever You Go- There You Are explains what m...
# 14  The Happiness Hypothesis is the most thorough ...
# 15  The More Of Less teaches you how to declutter ...
# ...
