# %% [markdown]
# # 3.7 Joins and Merges

# %%
import pandas as pd
df = pd.read_csv('senator_tweets.csv')

# %%
df
# Out:
#         Unnamed: 0        created_at  \
# 0                0  10/19/2017 21:47
# 1                1  10/19/2017 18:48
# 2                2  10/19/2017 18:14
# 3                3  10/19/2017 18:04
# 4                4  10/19/2017 16:33
# ...            ...               ...
# 288610      288610   7/28/2015 15:33
# 288611      288611   7/28/2015 15:32
# 288612      288612   7/27/2015 17:34
# 288613      288613   7/27/2015 17:30
# 288614      288614   7/26/2015 17:15
#
#                                                      text  \
# 0       We released bipartisan healthcare bill today &...
# 1       I spoke with @Morning_Joe team abt #HonestAds ...
# 2       Lots of interest in my bill with Senators Warn...
# 3       Today's the day @MarkWarner, @SenJohnMcCain &a...
# 4       .@MarkWarner, @SenJohnMcCain &amp; I put toget...
# ...                                                   ...
# 288610  Such a zone would allow the flow of unfettered...
# ...

# %%
bio_df = pd.read_csv('senator_bio.csv')

# %%
bio_df
# Out:
#   bioguide                                           bio_text
# 0  K000367  When I was younger I would sit underneath the ...
# 1  H001076  I always loved trains especially ones powered ...
# 2  B001267  Education has never been more important to me ...
# 3   A99939  Mass exodus to Mars has always been my backup ...

# %%
df = df.merge(bio_df, left_on='bioguide_id', right_on='bioguide', how='right', inplace=True)
