# %% [markdown]
# # Pandas Assignment 2
# In this assignment you will practice working with Pandas dataframes.
#
# Specifically, you will be carrying out the following excercises:
#
# 1. Work with Pandas indexes.
# 2. Use filtering to get subsets of dataframes.
# 3. Update rows and columns.
#
# ### Note about assignments
# You can add lines of code according to you preferences. As long as the code required by the assignment is found in this notebook file, you will receive credit for it regardless of the presence of additional code. You will lose points for removing starting code if it prevents the notebook from running correctly.
#
# ## About the data
# The data used in this assignment is a table built from the Human Resources schema of the Adventure Works 2019 database. This data contains information about each time that Employee Pay History was changed (each line is a pay rate change). It also contains information about the employee and the department they were working in when they received the pay rate listed.
#
# The actual data is stored in a `.csv` file located inside the `data` directory. The file is called `pay_history.csv`.

# %% [markdown]
# ##### Imports, dataframe, etc.
#
# Use the code below to show all columns in the dataframe:
#
# ```python
# pd.set_option('display.max_columns', None)
# ```

# %%
import pandas as pd

df = pd.read_csv("./data/pay_history.csv")
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Instructions
#
# Answer the questions below. Make sure to show your work and your answers as the output to the cells.
#
# ### Indexes
# ##### Question 1: Get the column `DepartmentName` as a Series object. Save it into a variable called `departmentSeries`.
#
# <p style="font-size:.75rem">Expected output: None</p>

# %%
departmentSeries = df['DepartmentName']

# %% [markdown]
# ##### Question 2: Get the value counts of each unique value in the `DepartmentName` series.
#
# <p style="font-size:.75rem">Expected output: Series of value counts for 16 unique department names.</p>

# %%
departmentSeries.value_counts()
# Out:
# Production                    180
# Sales                          18
# Purchasing                     15
# Marketing                      11
# Finance                        11
# Information Services           10
# Quality Assurance               8
# Engineering                     7
# Production Control              7
# Facilities and Maintenance      7
# Shipping and Receiving          6
# Human Resources                 6
# Tool Design                     5
# Document Control                5
# Executive                       4
# Research and Development        4
# Name: DepartmentName, dtype: int64

# %% [markdown]
# ##### Question 3: Use the `.loc` property to get rows 25, 80, and 122 and the `JobTitle` column.
#
# <p style="font-size:.75rem">Expected output: Series or dataframe from JobTitle column with three rows, indexes 25, 80, and 122. The job titles are Marketing Specialist, Production Technician - WC30, and Production Technician - WC50.</p>

# %%
df.loc[[25, 80, 122], "JobTitle"]
# Out:
# 25             Marketing Specialist
# 80     Production Technician - WC30
# 122    Production Technician - WC50
# Name: JobTitle, dtype: object

# %% [markdown]
# ##### Question 4: Did the previous question return a dataframe or a Series object? Why might this have happened?
#
# Remember that dataframes are formatted so that when you move your mouse over the rows, they change color. Series
#
# <p style="font-size:.75rem">Expected output: None</p>

# %% [markdown]
# ```
# The previous query returned a Series because only one column was selected. It would have also returned a Series if multiple columns but a single row was selected.
# ```

# %% [markdown]
# ##### Question 5: Get the first through sixth columns and the last 5 rows using `.iloc`
#
# <p style="font-size:.75rem">Expected output: Rows with indexes 298-302 and columns DepartmentID, RateChangeDate, Rate, PayFrequency, and LoginID</p>

# %%
df_length = df.shape[0]
df.iloc[df_length-6:df_length-1, 1:6]
# Out:
#      DepartmentID RateChangeDate     Rate  PayFrequency  \
# 298             3        00:00.0  48.1010             2
# 299             3        00:00.0  23.0769             2
# 300             3        00:00.0  48.1010             2
# 301             3        00:00.0  23.0769             2
# 302             3        00:00.0  23.0769             2
#
#                      LoginID
# 298    adventure-works\syed0
# 299    adventure-works\lynn0
# 300     adventure-works\amy0
# 301  adventure-works\rachel0
# 302     adventure-works\jae0

# %% [markdown]
# ### Filtering

# %% [markdown]
# ##### Question 6: Filter the dataframe to only include rows where the employee is in the `DepartmentName` Engineering.
#
# <p style="font-size:.75rem">Expected output: Rows with indexes 1, 2, 3, 6, 7, 15, and 16</p>

# %%
df.loc[ df['DepartmentName'] == 'Engineering' ]
# Out:
#     EmployeeID  DepartmentID RateChangeDate     Rate  PayFrequency  \
# 1            2             1        00:00.0  63.4615             2
# 2            3             1        00:00.0  43.2692             2
# 3            4             1        00:00.0   8.6200             2
# 6            5             1        00:00.0  32.6923             2
# 7            6             1        00:00.0  32.6923             2
# 15          14             1        00:00.0  36.0577             2
# 16          15             1        00:00.0  32.6923             2
#
#                      LoginID  OrganizationLevel  \
# 1     adventure-works\terri0                1.0
# 2   adventure-works\roberto0                2.0
# 3       adventure-works\rob0                3.0
# 6      adventure-works\gail0                3.0
# 7    adventure-works\jossef0                3.0
# 15  adventure-works\michael8                3.0
# 16   adventure-works\sharon0                3.0
#
#                          JobTitle   BirthDate MaritalStatus Gender  \
# 1   Vice President of Engineering    8/1/1971             S      F
# 2             Engineering Manager  11/12/1974             M      M
# 3            Senior Tool Designer  12/23/1974             S      M
# 6                 Design Engineer   9/27/1952             M      F
# 7                 Design Engineer   3/11/1959             M      M
# 15         Senior Design Engineer   6/16/1979             S      M
# 16                Design Engineer    5/2/1961             M      F
#
#       HireDate  SalariedFlag  VacationHours  SickLeaveHours  CurrentFlag  \
# 1    1/31/2008             1              1              20            1
# 2   11/11/2007             1              2              21            1
# 3    12/5/2007             0             48              80            1
# 6     1/6/2008             1              5              22            1
# 7    1/24/2008             1              6              23            1
# 15  12/30/2010             1              3              21            1
# 16   1/18/2011             1              4              22            1
#
#     ShiftID   StartDate    EndDate ModifiedDate DepartmentName  \
# 1         1   1/31/2008        NaN      00:00.0    Engineering
# 2         1  11/11/2007        NaN      00:00.0    Engineering
# 3         1   12/5/2007  5/30/2010      00:00.0    Engineering
# 6         1    1/6/2008        NaN      00:00.0    Engineering
# 7         1   1/24/2008        NaN      00:00.0    Engineering
# 15        1  12/30/2010        NaN      00:00.0    Engineering
# 16        1   1/18/2011        NaN      00:00.0    Engineering
#
#               Sub-Department
# 1   Research and Development
# 2   Research and Development
# 3   Research and Development
# 6   Research and Development
# 7   Research and Development
# 15  Research and Development
# 16  Research and Development

# %% [markdown]
# ##### Question 7: Filter the dataframe to include rows where the employee is either in the `DepartmentName` of Engineering or the `Sub-Department` of Quality Assurance.
#
# <p style="font-size:.75rem">Expected output: Rows with indexes 1-7, 15-16, 214-224, 259, and 261, or 20 rows total</p>

# %%
df[ (df['DepartmentName'] == 'Engineering') | (df['Sub-Department'] == 'Quality Assurance') ]
# Out:
#      EmployeeID  DepartmentID RateChangeDate     Rate  PayFrequency  \
# 1             2             1        00:00.0  63.4615             2
# 2             3             1        00:00.0  43.2692             2
# 3             4             1        00:00.0   8.6200             2
# 6             5             1        00:00.0  32.6923             2
# 7             6             1        00:00.0  32.6923             2
# 15           14             1        00:00.0  36.0577             2
# 16           15             1        00:00.0  32.6923             2
# 214         211            13        00:00.0  28.8462             2
# 215         212            13        00:00.0  21.6346             2
# 216         213            13        00:00.0  10.5769             2
# 217         214            13        00:00.0  10.5769             2
# 218         215            13        00:00.0  10.5769             2
# 219         216            13        00:00.0  10.5769             2
# 220         217            12        00:00.0  17.7885             2
# 221         218            12        00:00.0  16.8269             2
# 222         219            12        00:00.0  10.2500             2
# 223         220            12        00:00.0  10.2500             2
# 224         221            12        00:00.0  16.8269             2
# 259         250            13        00:00.0   9.8600             2
# 261         250            13        00:00.0  22.5000             2
#
#                       LoginID  OrganizationLevel  \
# 1      adventure-works\terri0                1.0
# 2    adventure-works\roberto0                2.0
# 3        adventure-works\rob0                3.0
# 6       adventure-works\gail0                3.0
# 7     adventure-works\jossef0                3.0
# 15   adventure-works\michael8                3.0
# 16    adventure-works\sharon0                3.0
# 214    adventure-works\hazem0                2.0
# 215     adventure-works\peng0                3.0
# 216   adventure-works\sootha0                4.0
# 217  adventure-works\andreas0                4.0
# 218     adventure-works\mark0                4.0
# 219     adventure-works\sean0                4.0
# 220   adventure-works\zainal0                3.0
# 221   adventure-works\tengiz0                4.0
# 222     adventure-works\sean1                4.0
# 223    adventure-works\karen0                4.0
# 224    adventure-works\chris1                4.0
# 259   adventure-works\sheela0                3.0
# 261   adventure-works\sheela0                3.0
#
#                           JobTitle   BirthDate MaritalStatus Gender  \
# 1    Vice President of Engineering    8/1/1971             S      F
# 2              Engineering Manager  11/12/1974             M      M
# 3             Senior Tool Designer  12/23/1974             S      M
# 6                  Design Engineer   9/27/1952             M      F
# 7                  Design Engineer   3/11/1959             M      M
# 15          Senior Design Engineer   6/16/1979             S      M
# 16                 Design Engineer    5/2/1961             M      F
# 214      Quality Assurance Manager  10/26/1977             S      M
# 215   Quality Assurance Supervisor   3/18/1976             M      M
# 216   Quality Assurance Technician   12/5/1966             M      M
# 217   Quality Assurance Technician   3/28/1989             M      M
# 218   Quality Assurance Technician   4/30/1986             S      M
# 219   Quality Assurance Technician    3/6/1976             S      M
# 220       Document Control Manager   1/30/1976             M      M
# 221             Control Specialist   4/28/1990             S      M
# 222     Document Control Assistant   3/12/1987             S      M
# 223     Document Control Assistant  12/25/1975             M      F
# 224             Control Specialist   5/26/1987             M      M
# 259             Purchasing Manager   2/10/1978             S      F
# 261             Purchasing Manager   2/10/1978             S      F
#
#        HireDate  SalariedFlag  VacationHours  SickLeaveHours  CurrentFlag  \
# 1     1/31/2008             1              1              20            1
# 2    11/11/2007             1              2              21            1
# 3     12/5/2007             0             48              80            1
# 6      1/6/2008             1              5              22            1
# 7     1/24/2008             1              6              23            1
# 15   12/30/2010             1              3              21            1
# 16    1/18/2011             1              4              22            1
# 214   2/28/2009             1             80              60            1
# 215   12/9/2008             1             81              60            1
# 216   2/23/2010             0             85              62            1
# 217    2/2/2009             0             84              62            1
# 218   1/15/2009             0             83              61            1
# 219  12/28/2008             0             82              61            1
# 220    1/4/2009             0             77              58            1
# 221  12/16/2008             0             76              58            1
# 222   1/22/2009             0             78              59            1
# 223    2/9/2009             0             79              59            1
# 224    3/6/2009             0             75              57            1
# 259   2/25/2011             1             49              44            1
# 261   2/25/2011             1             49              44            1
#
#      ShiftID   StartDate    EndDate ModifiedDate     DepartmentName  \
# 1          1   1/31/2008        NaN      00:00.0        Engineering
# 2          1  11/11/2007        NaN      00:00.0        Engineering
# 3          1   12/5/2007  5/30/2010      00:00.0        Engineering
# 6          1    1/6/2008        NaN      00:00.0        Engineering
# 7          1   1/24/2008        NaN      00:00.0        Engineering
# 15         1  12/30/2010        NaN      00:00.0        Engineering
# 16         1   1/18/2011        NaN      00:00.0        Engineering
# 214        1   2/28/2009        NaN      00:00.0  Quality Assurance
# 215        1   12/9/2008        NaN      00:00.0  Quality Assurance
# 216        3   2/23/2010        NaN      00:00.0  Quality Assurance
# 217        2    2/2/2009        NaN      00:00.0  Quality Assurance
# 218        1   1/15/2009        NaN      00:00.0  Quality Assurance
# 219        1  12/28/2008        NaN      00:00.0  Quality Assurance
# 220        1    1/4/2009        NaN      00:00.0   Document Control
# 221        3  12/16/2008        NaN      00:00.0   Document Control
# 222        1   1/22/2009        NaN      00:00.0   Document Control
# 223        1    2/9/2009        NaN      00:00.0   Document Control
# 224        2    3/6/2009        NaN      00:00.0   Document Control
# 259        1   7/31/2011  7/14/2012      00:00.0  Quality Assurance
# 261        1   7/31/2011  7/14/2012      00:00.0  Quality Assurance
#
#                Sub-Department
# 1    Research and Development
# 2    Research and Development
# 3    Research and Development
# 6    Research and Development
# 7    Research and Development
# 15   Research and Development
# 16   Research and Development
# 214         Quality Assurance
# 215         Quality Assurance
# 216         Quality Assurance
# 217         Quality Assurance
# 218         Quality Assurance
# 219         Quality Assurance
# 220         Quality Assurance
# 221         Quality Assurance
# 222         Quality Assurance
# 223         Quality Assurance
# 224         Quality Assurance
# 259         Quality Assurance
# 261         Quality Assurance

# %% [markdown]
# ##### Question 8: Filter the dataframe to only include rows with the word "Manager" in the `JobTitle`.
#
# <p style="font-size:.75rem">Expected output: 24 rows returned starting with row of index 2 and ending with row of index 300</p>

# %%
df.loc[ df['JobTitle'].str.contains("Manager") ]
# Out:
#      EmployeeID  DepartmentID RateChangeDate     Rate  PayFrequency  \
# 2             3             1        00:00.0  43.2692             2
# 8             7             6        00:00.0  50.4808             2
# 11           10             6        00:00.0  42.4808             2
# 17           16             5        00:00.0  24.0000             2
# 18           16             4        00:00.0  24.0000             2
# 19           16             4        00:00.0  28.7500             2
# 29           26             8        00:00.0  24.5192             2
# 214         211            13        00:00.0  28.8462             2
# 220         217            12        00:00.0  17.7885             2
# 232         227            14        00:00.0  24.0385             2
# 243         235             9        00:00.0  27.1394             2
# 249         241            10        00:00.0  34.7356             2
# 257         249            10        00:00.0  43.2692             2
# 258         250             4        00:00.0   9.8600             2
# 259         250            13        00:00.0   9.8600             2
# 260         250             5        00:00.0   9.8600             2
# 261         250            13        00:00.0  22.5000             2
# 262         250             5        00:00.0  22.5000             2
# 263         250             5        00:00.0  30.0000             2
# 276         263            11        00:00.0  50.4808             2
# 277         264            11        00:00.0  39.6635             2
# 287         274             3        00:00.0  48.1010             2
# 298         285             3        00:00.0  48.1010             2
# 300         287             3        00:00.0  48.1010             2
#
#                         LoginID  OrganizationLevel  \
# 2      adventure-works\roberto0                2.0
# 8        adventure-works\dylan0                3.0
# 11     adventure-works\michael6                4.0
# 17       adventure-works\david0                1.0
# 18       adventure-works\david0                1.0
# 19       adventure-works\david0                1.0
# 29       adventure-works\peter0                2.0
# 214      adventure-works\hazem0                2.0
# 220     adventure-works\zainal0                3.0
# 232       adventure-works\gary1                2.0
# 243      adventure-works\paula0                2.0
# 249      adventure-works\david6                2.0
# 257      adventure-works\wendy0                2.0
# 258     adventure-works\sheela0                3.0
# 259     adventure-works\sheela0                3.0
# 260     adventure-works\sheela0                3.0
# 261     adventure-works\sheela0                3.0
# 262     adventure-works\sheela0                3.0
# 263     adventure-works\sheela0                3.0
# 276       adventure-works\jean0                1.0
# 277  adventure-works\stephanie0                2.0
# 287    adventure-works\stephen0                2.0
# 298       adventure-works\syed0                2.0
# 300        adventure-works\amy0                2.0
#
#                              JobTitle   BirthDate MaritalStatus Gender  \
# 2                 Engineering Manager  11/12/1974             M      M
# 8    Research and Development Manager   2/24/1987             M      M
# 11   Research and Development Manager  11/30/1984             M      M
# 17                  Marketing Manager   3/19/1975             S      M
# 18                  Marketing Manager   3/19/1975             S      M
# 19                  Marketing Manager   3/19/1975             S      M
# 29         Production Control Manager   11/3/1982             M      M
# 214         Quality Assurance Manager  10/26/1977             S      M
# 220          Document Control Manager   1/30/1976             M      M
# 232                Facilities Manager   2/18/1971             M      M
# 243           Human Resources Manager   2/11/1976             M      F
# 249                  Accounts Manager    7/8/1983             M      M
# 257                   Finance Manager  10/11/1984             S      F
# 258                Purchasing Manager   2/10/1978             S      F
# 259                Purchasing Manager   2/10/1978             S      F
# 260                Purchasing Manager   2/10/1978             S      F
# 261                Purchasing Manager   2/10/1978             S      F
# 262                Purchasing Manager   2/10/1978             S      F
# 263                Purchasing Manager   2/10/1978             S      F
# 276      Information Services Manager  12/13/1975             S      F
# 277                   Network Manager   3/25/1984             S      F
# 287      North American Sales Manager  10/17/1951             M      M
# 298             Pacific Sales Manager   1/11/1975             M      M
# 300            European Sales Manager   9/20/1957             M      F
#
#        HireDate  SalariedFlag  VacationHours  SickLeaveHours  CurrentFlag  \
# 2    11/11/2007             1              2              21            1
# 8      2/8/2009             1             61              50            1
# 11     5/3/2009             1             16              64            1
# 17   12/20/2007             1             40              40            1
# 18   12/20/2007             1             40              40            1
# 19   12/20/2007             1             40              40            1
# 29    12/1/2008             1             43              41            1
# 214   2/28/2009             1             80              60            1
# 220    1/4/2009             0             77              58            1
# 232   12/2/2009             1             86              63            1
# 243   12/6/2008             1             54              47            1
# 249   1/30/2009             1             57              48            1
# 257  12/25/2008             1             55              47            1
# 258   2/25/2011             1             49              44            1
# 259   2/25/2011             1             49              44            1
# 260   2/25/2011             1             49              44            1
# 261   2/25/2011             1             49              44            1
# 262   2/25/2011             1             49              44            1
# 263   2/25/2011             1             49              44            1
# 276  12/11/2008             1             65              52            1
# 277    2/4/2009             1             68              54            1
# 287    1/4/2011             1             14              27            1
# 298   3/14/2013             1             20              30            1
# 300   4/16/2012             1             21              30            1
#
#      ShiftID   StartDate    EndDate ModifiedDate              DepartmentName  \
# 2          1  11/11/2007        NaN      00:00.0                 Engineering
# 8          1    2/8/2009        NaN      00:00.0    Research and Development
# 11         1    5/3/2009        NaN      00:00.0    Research and Development
# 17         1  12/20/2007  7/14/2009      00:00.0                  Purchasing
# 18         1   7/15/2009        NaN      00:00.0                   Marketing
# 19         1   7/15/2009        NaN      00:00.0                   Marketing
# 29         1   12/1/2008        NaN      00:00.0          Production Control
# 214        1   2/28/2009        NaN      00:00.0           Quality Assurance
# 220        1    1/4/2009        NaN      00:00.0            Document Control
# 232        1   12/2/2009        NaN      00:00.0  Facilities and Maintenance
# 243        1   12/6/2008        NaN      00:00.0             Human Resources
# 249        1   1/30/2009        NaN      00:00.0                     Finance
# 257        1  12/25/2008        NaN      00:00.0                     Finance
# 258        1   2/25/2011  7/30/2011      00:00.0                   Marketing
# 259        1   7/31/2011  7/14/2012      00:00.0           Quality Assurance
# 260        1   7/15/2012        NaN      00:00.0                  Purchasing
# 261        1   7/31/2011  7/14/2012      00:00.0           Quality Assurance
# 262        1   7/15/2012        NaN      00:00.0                  Purchasing
# 263        1   7/15/2012        NaN      00:00.0                  Purchasing
# 276        1  12/11/2008        NaN      00:00.0        Information Services
# 277        1    2/4/2009        NaN      00:00.0        Information Services
# 287        1    1/4/2011        NaN      00:00.0                       Sales
# 298        1   3/14/2013        NaN      00:00.0                       Sales
# 300        1   4/16/2012        NaN      00:00.0                       Sales
#
#                            Sub-Department
# 2                Research and Development
# 8                Research and Development
# 11               Research and Development
# 17                   Inventory Management
# 18                    Sales and Marketing
# 19                    Sales and Marketing
# 29                          Manufacturing
# 214                     Quality Assurance
# 220                     Quality Assurance
# 232  Executive General and Administration
# 243  Executive General and Administration
# 249  Executive General and Administration
# 257  Executive General and Administration
# 258                   Sales and Marketing
# 259                     Quality Assurance
# 260                  Inventory Management
# 261                     Quality Assurance
# 262                  Inventory Management
# 263                  Inventory Management
# 276  Executive General and Administration
# 277  Executive General and Administration
# 287                   Sales and Marketing
# 298                   Sales and Marketing
# 300                   Sales and Marketing

# %% [markdown]
# ##### Question 9: Get a dataframe of all employees who are not salaried, are married, and work in the `Department` of Finance.
#
# <p style="font-size:.75rem">Expected output: 3 rows, indexes 251, 252, 275</p>

# %%
df.loc[ ~(df['SalariedFlag'] == 1) & (df['MaritalStatus'] == 'S') & (df['DepartmentName'] == 'Finance')]
# Out:
#      EmployeeID  DepartmentID RateChangeDate     Rate  PayFrequency  \
# 251         243            10        00:00.0  19.0000             2
# 252         244            10        00:00.0  19.0000             2
# 275         262            10        00:00.0  13.4615             2
#
#                     LoginID  OrganizationLevel  \
# 251  adventure-works\candy0                3.0
# 252  adventure-works\bryan1                3.0
# 275  adventure-works\david5                2.0
#
#                                      JobTitle  BirthDate MaritalStatus Gender  \
# 251            Accounts Receivable Specialist  2/23/1976             S      F
# 252            Accounts Receivable Specialist  9/20/1984             S      M
# 275  Assistant to the Chief Financial Officer  6/21/1964             S      M
#
#       HireDate  SalariedFlag  VacationHours  SickLeaveHours  CurrentFlag  \
# 251   1/6/2009             0             61              50            1
# 252  1/24/2009             0             62              51            1
# 275  1/12/2009             0             56              48            1
#
#      ShiftID  StartDate EndDate ModifiedDate DepartmentName  \
# 251        1   1/6/2009     NaN      00:00.0        Finance
# 252        1  1/24/2009     NaN      00:00.0        Finance
# 275        1  1/12/2009     NaN      00:00.0        Finance
#
#                            Sub-Department
# 251  Executive General and Administration
# 252  Executive General and Administration
# 275  Executive General and Administration

# %% [markdown]
# ##### Question 10: Get a dataframe of all employees hired in 2009 who are paid more than $40 per hour. Remember that Pandas currently thinks that the `HireDate` field is a string (use this as an advantage).
#
# <p style="font-size:.75rem">Expected output: 7 rows starting with index 0 and ending with index 242</p>

# %%
df.loc[ (df['HireDate'].str.contains('2009')) & (df['Rate'] > 40) ]
# Out:
#      EmployeeID  DepartmentID RateChangeDate      Rate  PayFrequency  \
# 0             1            16        00:00.0  125.5000             2
# 8             7             6        00:00.0   50.4808             2
# 10            9             6        00:00.0   40.8654             2
# 11           10             6        00:00.0   42.4808             2
# 28           25             7        00:00.0   84.1346             2
# 241         234            16        00:00.0   48.5577             2
# 242         234            16        00:00.0   60.0962             2
#
#                       LoginID  OrganizationLevel  \
# 0        adventure-works\ken0                NaN
# 8      adventure-works\dylan0                3.0
# 10      adventure-works\gigi0                4.0
# 11   adventure-works\michael6                4.0
# 28     adventure-works\james1                1.0
# 241    adventure-works\laura1                1.0
# 242    adventure-works\laura1                1.0
#
#                               JobTitle   BirthDate MaritalStatus Gender  \
# 0              Chief Executive Officer   1/29/1969             S      M
# 8     Research and Development Manager   2/24/1987             M      M
# 10   Research and Development Engineer   1/21/1979             M      F
# 11    Research and Development Manager  11/30/1984             M      M
# 28        Vice President of Production    1/7/1983             S      M
# 241            Chief Financial Officer    1/6/1976             M      F
# 242            Chief Financial Officer    1/6/1976             M      F
#
#       HireDate  SalariedFlag  VacationHours  SickLeaveHours  CurrentFlag  \
# 0    1/14/2009             1             99              69            1
# 8     2/8/2009             1             61              50            1
# 10   1/16/2009             1             63              51            1
# 11    5/3/2009             1             16              64            1
# 28    2/3/2009             1             64              52            1
# 241  1/31/2009             1              0              20            1
# 242  1/31/2009             1              0              20            1
#
#      ShiftID   StartDate EndDate ModifiedDate            DepartmentName  \
# 0          1   1/14/2009     NaN      00:00.0                 Executive
# 8          1    2/8/2009     NaN      00:00.0  Research and Development
# 10         1   1/16/2009     NaN      00:00.0  Research and Development
# 11         1    5/3/2009     NaN      00:00.0  Research and Development
# 28         1    2/3/2009     NaN      00:00.0                Production
# 241        1  11/14/2013     NaN      00:00.0                 Executive
# 242        1  11/14/2013     NaN      00:00.0                 Executive
#
#                            Sub-Department
# 0    Executive General and Administration
# 8                Research and Development
# 10               Research and Development
# 11               Research and Development
# 28                          Manufacturing
# 241  Executive General and Administration
# 242  Executive General and Administration

# %% [markdown]
# ### Updating Rows and Columns
#
# ##### Question 11: Change the column names to be all lowercase. Make sure that this change is reflected in the original dataframe (ie. print it out).
#
# <p style="font-size:.75rem">Expected output: DataFrame with lowercase column names</p>

# %%
df.columns = df.columns.str.lower()

# %% [markdown]
# ##### Question 12: Use the `.map()` method to change the values in the `maritalstatus` column to say either Married or Not Married.
#
# <p style="font-size:.75rem">Expected output: A Series whose values are either "Not Married" or "Married"</p>

# %%
df['maritalstatus'].map({"M" : "Married", "S": "Not Married"})
# Out:
# 0      Not Married
# 1      Not Married
# 2          Married
# 3      Not Married
# 4      Not Married
#           ...
# 299    Not Married
# 300        Married
# 301    Not Married
# 302        Married
# 303    Not Married
# Name: maritalstatus, Length: 304, dtype: object

# %% [markdown]
# ##### Question 13: Use the `.replace()` method to replace "Chief Executive Office" with "President and CEO" in the column `jobtitle`. Show the first five rows of the dataframe.
#
# <p style="font-size:.75rem">Expected output: 5 rows, indexes 0-4</p>

# %%
df['jobtitle'] = df['jobtitle'].replace({'Chief Executive Officer': 'President and CEO'})
df.head()
# Out:
#    employeeid  departmentid ratechangedate      rate  payfrequency  \
# 0           1            16        00:00.0  125.5000             2
# 1           2             1        00:00.0   63.4615             2
# 2           3             1        00:00.0   43.2692             2
# 3           4             1        00:00.0    8.6200             2
# 4           4             2        00:00.0    8.6200             2
#
#                     loginid  organizationlevel                       jobtitle  \
# 0      adventure-works\ken0                NaN              President and CEO
# 1    adventure-works\terri0                1.0  Vice President of Engineering
# 2  adventure-works\roberto0                2.0            Engineering Manager
# 3      adventure-works\rob0                3.0           Senior Tool Designer
# 4      adventure-works\rob0                3.0           Senior Tool Designer
#
#     birthdate maritalstatus gender    hiredate  salariedflag  vacationhours  \
# 0   1/29/1969             S      M   1/14/2009             1             99
# 1    8/1/1971             S      F   1/31/2008             1              1
# 2  11/12/1974             M      M  11/11/2007             1              2
# 3  12/23/1974             S      M   12/5/2007             0             48
# 4  12/23/1974             S      M   12/5/2007             0             48
#
#    sickleavehours  currentflag  shiftid   startdate    enddate modifieddate  \
# 0              69            1        1   1/14/2009        NaN      00:00.0
# 1              20            1        1   1/31/2008        NaN      00:00.0
# 2              21            1        1  11/11/2007        NaN      00:00.0
# 3              80            1        1   12/5/2007  5/30/2010      00:00.0
# 4              80            1        1   5/31/2010        NaN      00:00.0
#
#   departmentname                        sub-department
# 0      Executive  Executive General and Administration
# 1    Engineering              Research and Development
# 2    Engineering              Research and Development
# 3    Engineering              Research and Development
# 4    Tool Design              Research and Development

# %% [markdown]
# ##### EXTRA CREDIT Question 14: Create a function that can grab the employee's username out of the `loginid`. Apply the function to the `loginid` Series.
#
# Use the function `get_username()` provided to you below and apply it to the column `loginid` using the `.apply()` method. Note that you do not need to save this new Series as a column since that has not been covered yet.
#
# <p style="font-size:.75rem">Expected output: A Series of usernames, starting with "ken0", "terri0", "roberto0", etc.</p>

# %%
def get_username(login):
    return login.split('\\')[-1]

df['loginid'].apply(get_username)
# Out:
# 0          ken0
# 1        terri0
# 2      roberto0
# 3          rob0
# 4          rob0
#          ...
# 299       lynn0
# 300        amy0
# 301     rachel0
# 302        jae0
# 303     ranjit0
# Name: loginid, Length: 304, dtype: object

# %% [markdown]
# ##### EXTRA CREDIT Question 15: Use the `.apply()` method to change the `rate` column to be rounded to two decimal places.
#
# Use the function `round_to_two_decimals()` provided to you below and apply it to the column `rate` using the `.apply()` method. Note that you do not need to save this new Series as a column since that has not been covered yet.
#
# <p style="font-size:.75rem">Expected output: A Series of decimal numbers, rounded to two decimal places and starting with 125.50, 63.46, and 43.27</p>

# %%
def round_to_two_decimals(rate):
    return round(rate,2)

df['rate'].apply(round_to_two_decimals)
# Out:
# 0      125.50
# 1       63.46
# 2       43.27
# 3        8.62
# 4        8.62
#         ...
# 299     23.08
# 300     48.10
# 301     23.08
# 302     23.08
# 303     23.08
# Name: rate, Length: 304, dtype: float64
